# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#                     Name  Year of release                   Aired Date  \
# 0         Move to Heaven             2021                 May 14, 2021
# 1      Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2         Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3              My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4        Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# ..                   ...              ...                          ...
# 95  Thirty But Seventeen             2018  Jul 23, 2018 - Sep 18, 2018
# 96              Vagabond             2019  Sep 20, 2019 - Nov 23, 2019
# 97       Be Melodramatic             2019  Aug  9, 2019 - Sep 28, 2019
# 98    Mad for Each Other             2021  May 24, 2021 - Jun 21, 2021
# 99    The Princess's Man             2011  Jul 20, 2011 - Oct  6, 2011
#
#                        Aired On  Number of Episode  \
# 0                        Friday                 10
# ...

# %%
df.head()
# Out:
#                 Name  Year of release                   Aired Date  \
# 0     Move to Heaven             2021                 May 14, 2021
# 1  Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2     Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3          My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4    Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
#
#                Aired On  Number of Episode  \
# 0                Friday                 10
# 1              Thursday                 12
# 2   Wednesday, Thursday                 16
# 3   Wednesday, Thursday                 16
# 4   Wednesday, Thursday                 16
#
#                                         Network       Duration  \
# 0        Netflix,  Netflix,  Netflix,  Netflix         52 min.
# 1  tvN,  Netflix,  Netflix,  Netflix,  Netflix   1 hr. 30 min.
# 2                                          tvN   1 hr. 10 min.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Year of release  Number of Episode      Rating
# count       100.000000         100.000000  100.000000
# mean       2017.680000          19.530000    8.703000
# std           2.827999          12.307881    0.178351
# min        2003.000000           6.000000    8.500000
# 25%        2016.750000          16.000000    8.600000
# 50%        2018.000000          16.000000    8.700000
# 75%        2020.000000          20.000000    8.800000
# max        2021.000000         100.000000    9.200000

# %%
df.shape
# Out:
# (100, 14)

# %%
df.columns
# Out:
# Index(['Name', 'Year of release', 'Aired Date', 'Aired On',
#        'Number of Episode', 'Network', 'Duration', 'Content Rating',
#        'Synopsis', 'Cast', 'Genre', 'Tags', 'Rank', 'Rating'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.astype
# Out:
# <bound method NDFrame.astype of                     Name  Year of release                   Aired Date  \
# 0         Move to Heaven             2021                 May 14, 2021
# 1      Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2         Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3              My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4        Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# ..                   ...              ...                          ...
# 95  Thirty But Seventeen             2018  Jul 23, 2018 - Sep 18, 2018
# 96              Vagabond             2019  Sep 20, 2019 - Nov 23, 2019
# 97       Be Melodramatic             2019  Aug  9, 2019 - Sep 28, 2019
# 98    Mad for Each Other             2021  May 24, 2021 - Jun 21, 2021
# 99    The Princess's Man             2011  Jul 20, 2011 - Oct  6, 2011
#
#                        Aired On  Number of Episode  \
# ...

# %%
df.sort_values(by=['Number of Episode'])
# Out:
#                          Name  Year of release                   Aired Date  \
# 23                    Kingdom             2019                 Jan 25, 2019
# 46  Arthdal Chronicles Part 3             2019  Sep  7, 2019 - Sep 22, 2019
# 38  Arthdal Chronicles Part 2             2019  Jun 22, 2019 - Jul  7, 2019
# 14                    Kingdom             2020                 Mar 13, 2020
# 90  Arthdal Chronicles Part 1             2019  Jun  1, 2019 - Jun 16, 2019
# ..                        ...              ...                          ...
# 30         Six Flying Dragons             2015  Oct  5, 2015 - Mar 22, 2016
# 66                 Empress Ki             2013  Oct 28, 2013 - Apr 29, 2014
# 57       My Father is Strange             2017  Mar  4, 2017 - Aug 27, 2017
# 64        Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 81                 Once Again             2020  Mar 28, 2020 - Sep 13, 2020
#
#              Aired On  Number of Episode  \
# ...

# %%
df['Year of release'].value_counts()
# Out:
# 2020    20
# 2017    17
# 2019    17
# 2018    11
# 2021    10
# 2016     9
# 2013     5
# 2014     4
# 2015     3
# 2012     2
# 2003     1
# 2011     1
# Name: Year of release, dtype: int64

# %%
df.drop_duplicates()
# Out:
#                     Name  Year of release                   Aired Date  \
# 0         Move to Heaven             2021                 May 14, 2021
# 1      Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2         Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3              My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4        Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# ..                   ...              ...                          ...
# 95  Thirty But Seventeen             2018  Jul 23, 2018 - Sep 18, 2018
# 96              Vagabond             2019  Sep 20, 2019 - Nov 23, 2019
# 97       Be Melodramatic             2019  Aug  9, 2019 - Sep 28, 2019
# 98    Mad for Each Other             2021  May 24, 2021 - Jun 21, 2021
# 99    The Princess's Man             2011  Jul 20, 2011 - Oct  6, 2011
#
#                        Aired On  Number of Episode  \
# 0                        Friday                 10
# ...
