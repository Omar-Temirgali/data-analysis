# %% [markdown]
# ## Welcome to Quiz 1

# %%
ID: 190103312

# %%
Name & Surname: Saya Baibossynova

# %% [markdown]
# **Data exploration can be overwhelming for anyone who has little to no background in data analysis. There is technically no limits to what you can explore and there is no guidelines to what you should be looking for. But as the saying goes this quiz attempts to lay down not one but five easy steps you can follow while you’re exploring a dataset and in order to pass this quiz. I (person: quiz taker) call it LAUGH:**
#
# #### **Step 1:** L-oad the data
# #### Step 2: A-sk for definitions
# #### Step 3: U-se questions
# #### Step 4: G-et a feel
# #### Step 5: H-ave next actions

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### STEP 1: Load the data (5 points)
#
# We start LAUGH-ing by loading our data into a Jupyter notebook.
#
# **Task:**
# - Load the dataset from dataset folder by using pandas library: File name: <ins>dataset.csv</ins>

# %%
## your code here:
import pandas as pd

df = pd.read_csv('dataset.csv')

# %% [markdown]
# ------------------------------

# %% [markdown]
# ### STEP 2: Ask for definitions (10 points)
#
# Perhaps the most underrated step of any dataset exploration is the one that deals with understanding the variables inside it. Having a good grasp of what each column header means will help form a story in your head as to what variables are likely to be important and which ones are likely okay to ignore.
#
# Familiarizing yourself with how the columns were sourced and measured will make your exploration easier. It will enable you to anticipate risks such as missing data, data duplicates and biases in the data.
#
# **Task:**
# - In the folder dataset, you can find <ins>definitions.txt</ins> file. Your task concludes on how you understand defenitions and explain with your own words what columns are in the dataset. \
#
# **Important Note: Some datasets can not have column definitions, column names can say itself what they mean.**

# %%
# Explain the definitions here
# Columns in the dataset are main sections that can help us to explore data. They can help us to see certain information
# about each item or process. In my case columns are 'Name', 'Year of release', 'Genre' and so on. These are about 
# Korean Shows (Dramas).

# %% [markdown]
# ------------------------------

# %% [markdown]
# ### Step 3: Use questions (15 points)
#
# Using questions is the smartest thing you can do during an EDA (a fancier term for data exploration, stands for Exploratory Data Analysis). As the cheshire cat says “.. if you don’t know where you are going, any road will take you there.” To avoid being sucked into the black hole that is EDA, pause and list out your questions first before writing any code. This will allow you to specify which variables you care about, what to do with them and when to stop the exploration **Remember, the data is only as good as the questions it’s trying to answer.**
#
# **Task**
# - After discovering all definitions, I (the quiz taker) hope, you have some idea about the data. Your task here is to generate 3 questions related to data. **Requirements**:
#     - Your question must include minimum 2 columns
#     - Your question must be medium level question (not too easy and not easy to answer, example given below)
#     - You should answer to your question in step 4, so you need to compose answerable questions
#
# **Not preferable question:** Is it possible to use pandas apply function to this dataset? \
# **Good question:**
# Which values are rare? Why? Does that match your expectations?! (it is not allowed to use this example, but you can answer it)\
# Is there any relationship between who a person works for and their performance score?\
# What is the overall diversity profile of the organization?\
# What are our best recruiting sources if we want to ensure a diverse organization?\
# Can we predict who is going to terminate and who isn't? What level of accuracy can we achieve on this?\
# Are there areas of the company where pay is not equitable?\

# %%
# Question 1
# In which days usually do dramas air on?

# %%
# Question 2 
# Which genres have the most rating?

# %%
# Question 3
# In which year the most drama was

# %% [markdown]
# ----------------

# %% [markdown]
# ### Step 4: Get a feel (55 points)
#
# This step is the heart of the exploration. This is where we actually look at the data with the goal of developing an intuition by spotting patterns and anomalies.
#
# **In this section you need to complete several tasks groups (this section more related to coding)**

# %% [markdown]
# #### Task 1: Explore the data (15 points)
#
# **Here are listed pandas and numpy function. Your task is to perform some manipulation on data using those functions.**\
# **<ins>Note:</ins> Some functions involve several columns to perform, and it is denoted in brackets **\
#
# 1. Head
# 2. Info
# 3. Describe
# 4. Shape
# 5. Columns & Index
# 6. astype
# 7. Sort values (use 2 columns)
# 8. value_counts
# 9. drop_duplicates (use 3 columns)
# 10. Subsetting
# 11. Adding a new column
# 12. Set Index & Reset index
# 13. loc & iloc
# 14. groupBy (use 3 columns)
# 15. Pivot table

# %%
# Head
df.head()
# Out:
#                 Name  Year of release                   Aired Date  \
# 0     Move to Heaven             2021                 May 14, 2021
# 1  Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2     Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3          My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4    Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
#
#                Aired On  Number of Episode  \
# 0                Friday                 10
# 1              Thursday                 12
# 2   Wednesday, Thursday                 16
# 3   Wednesday, Thursday                 16
# 4   Wednesday, Thursday                 16
#
#                                         Network       Duration  \
# 0        Netflix,  Netflix,  Netflix,  Netflix         52 min.
# 1  tvN,  Netflix,  Netflix,  Netflix,  Netflix   1 hr. 30 min.
# 2                                          tvN   1 hr. 10 min.
# ...

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
# Describe
df.describe()
# Out:
#        Year of release  Number of Episode      Rating
# count       100.000000         100.000000  100.000000
# mean       2017.680000          19.530000    8.703000
# std           2.827999          12.307881    0.178351
# min        2003.000000           6.000000    8.500000
# 25%        2016.750000          16.000000    8.600000
# 50%        2018.000000          16.000000    8.700000
# 75%        2020.000000          20.000000    8.800000
# max        2021.000000         100.000000    9.200000

# %%
# Shape
df.shape
# Out:
# (100, 14)

# %%
# Columns & Index
df.columns
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
# astype

# %%
# Sort values
df.sort_values(['Year of release', 'Number of Episode'], ascending=[False, True])
# Out:
#                    Name  Year of release                   Aired Date  \
# 0        Move to Heaven             2021                 May 14, 2021
# 8             Navillera             2021  Mar 22, 2021 - Apr 27, 2021
# 36         Youth of May             2021  May  3, 2021 - Jun  8, 2021
# 20      The Penthouse 2             2021  Feb 19, 2021 - Apr  2, 2021
# 98   Mad for Each Other             2021  May 24, 2021 - Jun 21, 2021
# ..                  ...              ...                          ...
# 66           Empress Ki             2013  Oct 28, 2013 - Apr 29, 2014
# 76           Reply 1997             2012  Jul 24, 2012 - Sep 18, 2012
# 55      The Bridal Mask             2012  May 30, 2012 - Sep  6, 2012
# 99   The Princess's Man             2011  Jul 20, 2011 - Oct  6, 2011
# 64  Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
#
#                        Aired On  Number of Episode  \
# 0                        Friday                 10
# ...

# %%
# value_counts
df['Year of release'].value_counts()
# Out:
# 2020    20
# 2017    17
# 2019    17
# 2018    11
# 2021    10
# 2016     9
# 2013     5
# 2014     4
# 2015     3
# 2012     2
# 2003     1
# 2011     1
# Name: Year of release, dtype: int64

# %%
# drop_duplicates
df.drop_duplicates()
# Out:
#                     Name  Year of release                   Aired Date  \
# 0         Move to Heaven             2021                 May 14, 2021
# 1      Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2         Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3              My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4        Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# ..                   ...              ...                          ...
# 95  Thirty But Seventeen             2018  Jul 23, 2018 - Sep 18, 2018
# 96              Vagabond             2019  Sep 20, 2019 - Nov 23, 2019
# 97       Be Melodramatic             2019  Aug  9, 2019 - Sep 28, 2019
# 98    Mad for Each Other             2021  May 24, 2021 - Jun 21, 2021
# 99    The Princess's Man             2011  Jul 20, 2011 - Oct  6, 2011
#
#                        Aired On  Number of Episode  \
# 0                        Friday                 10
# ...

# %%
# Subsetting
df[df['Rating'] > 9.0]
# Out:
#                 Name  Year of release                   Aired Date  \
# 0     Move to Heaven             2021                 May 14, 2021
# 1  Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2     Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3          My Mister             2018  Mar 21, 2018 - May 17, 2018
# 4    Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
#
#                Aired On  Number of Episode  \
# 0                Friday                 10
# 1              Thursday                 12
# 2   Wednesday, Thursday                 16
# 3   Wednesday, Thursday                 16
# 4   Wednesday, Thursday                 16
#
#                                         Network       Duration  \
# 0        Netflix,  Netflix,  Netflix,  Netflix         52 min.
# 1  tvN,  Netflix,  Netflix,  Netflix,  Netflix   1 hr. 30 min.
# 2                                          tvN   1 hr. 10 min.
# ...

# %%
# Adding a new column
df['Countries that watch most'] = countries

# %%
# Set Index & Reset index

# %%
# loc & iloc
df.loc[10, 'Cast']
df.iloc[0:6, 0:4]
# Out:
#                        Name Year of release                   Aired Date  \
# 0            Move to Heaven            2021                 May 14, 2021
# 1         Hospital Playlist            2020  Mar 12, 2020 - May 28, 2020
# 2            Flower of Evil            2020  Jul 29, 2020 - Sep 23, 2020
# 3                 My Mister            2018  Mar 21, 2018 - May 17, 2018
# 4           Prison Playbook            2017  Nov 22, 2017 - Jan 18, 2018
# 5  It's Okay to Not Be Okay            2020  Jun 20, 2020 - Aug  9, 2020
#
#                Aired On
# 0                Friday
# 1              Thursday
# 2   Wednesday, Thursday
# 3   Wednesday, Thursday
# 4   Wednesday, Thursday
# 5      Saturday, Sunday

# %%
# groupBy
df.groupBy(['Year of release', 'Number of Episodes', 'Duration']).count()

# %%
# Pivot table

# %% [markdown]
# --------------------

# %% [markdown]
# #### Bonus part

# %%
# Explore the dataset
# This tab is free mode. This section will count as a bonus part. 
#If you show up more interesting facts in your dataset, instructor can give bonuses. More facts, more bonuses

# %% [markdown]
# #### Task 2: Answer general questions by manipulation the dataset (20 points)
#
# **In this section you task is to answer questions below by using python, pandas, numpy. Requirements: Using of python and python libraries you need to complete questions below by manipulation the dataset.**\

# %%
# Question 1. Which values are the most common? Why?
df['Year of release'].value_counts()

# Numbers of dramas that was released in 2020 are most because of the popularity Korean culture and Kpop
# Out:
# 2020      20
# 2017      17
# 2019      17
# 2018      11
# 2021      10
# 2016       9
# 2013       5
# 2014       4
# 2015       3
# 2012       2
# Friday     1
# 2003       1
# 2011       1
# Name: Year of release, dtype: int64

# %%
# Question 2. Can you see any unusual patterns? What might explain them?

# %%
# Question 3. Which values are rare? Why? Does that match your expectations?

df['Year of release'].value_counts()

# Drama that was aired in 2011 is the only one in the dataset. Yes, id does match because these kind of shows are too
# old, old plot and story and so on.
# Out:
# 2020      20
# 2017      17
# 2019      17
# 2018      11
# 2021      10
# 2016       9
# 2013       5
# 2014       4
# 2015       3
# 2012       2
# Friday     1
# 2003       1
# 2011       1
# Name: Year of release, dtype: int64

# %% [markdown]
# #### Task 3: On the way finding answers to my goals (questions) (20 points)
#
# **In this section you task is to answer to your questions in step 3 by using python, pandas, numpy. Requirements: Using of python and python libraries you need to complete your goals by manipulation the dataset.**\

# %%
# Question 1
# (please copy & paste your question here)
# perform some manipulations

# %%
# Question 2
# (please copy & paste your question here)
# perform some manipulations

# %%
# Question 3
# (please copy & paste your question here)
# perform some manipulations

# %% [markdown]
# ### Step 5: Have next actions (15 points)
#
# Finally, the last step is a reminder that EDAs are just that- an exploration. There is no need to burn ourselves out with complex data treatment at this stage. The goal is to develop our own intuition of the dataset in preparation for the next action. This maybe hypothesis testing, feature engineering or simply filling out missing data. Whatever it is, listing them out will help give a sense of accomplishment to our exploration. Because that would mean that we’ve done what we set out to do during exploration and are now ready to dig deeper into the data.
#
# **Task: Please, answer those question below**
#
# - **What *they expect to learn from the data?** *(in this case you are the data engineer and your principle need some imagination about your data)
# - **How much time they can spend analyzing data?**
# - **Summary must be writen with your own words!**

# %%
# What they expect to learn from the data? Why?
# They expect observations of certain developments of processes

# %%
# How much time they can spend analyzing data? Why?
# It depends on the field and sizes

# %%
# Your summary to your work with your own words!
# My summary to my work is that korean dramas getting popular nowadays and most recent aired dramas has best rankings

# %% [markdown]
# --------

# %% [markdown]
# ### Submit your work:
#
# **Please follow the link in order to submit your work:** https://forms.gle/w4guB9nYkqDZn2jd6
